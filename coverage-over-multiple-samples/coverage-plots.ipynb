# %%
def plot_cov(file, contig_index):
    for line in open(file):
        dat = line.rstrip().split(' ')
        id, bp, avg, stddev = dat
        bp = int(bp)
        if d.has_key(id):
            d[id][bp] = float(avg)
        else:
            d[id] = {}
            d[id][bp] = float(avg)
    print len(d.keys())
    for n, key in enumerate(d.keys()):
        if n == contig_index:
            contig_key = key
            x_val = d[key].keys()
            y_val = d[key].values()

    return(x_val, y_val, contig_key)

def plot_cov2(file, contig_index):
    for line in open(file):
        dat = line.rstrip().split(' ')
        id, bp, avg, stddev = dat
        bp = int(bp)
        if d.has_key(id):
            d[id][bp] = float(avg)
        else:
            d[id] = {}
            d[id][bp] = float(avg)

    for n, key in enumerate(d.keys()):
        if n == contig_index:
            x_val = d[key].keys()
            y_val = d[key].values()

    return(x_val, y_val)

d = {}

contig = 3

rcParams['figure.figsize'] = 10, 5
x1, y1, key = plot_cov("50_2-12_total", contig)
x3, y3, key = plot_cov("50_3-6_total", contig)
x4, y4, key = plot_cov("50_3-27_total", contig)

ax = subplot(2,3,1)
ax.set_title(key)
ax.plot(x1,y1, label="t1", color="black", ls="solid")
ax.plot(x3,y3, label="t3", color="red", ls="solid")
ax.plot(x4,y4, label="t4", color="blue", ls="dotted")
tickies = map(int, ax.xaxis.get_majorticklocs())
ax.set_xticklabels(tickies, rotation=90 )
y_formatter = matplotlib.ticker.ScalarFormatter(useOffset=False)
ax.yaxis.set_major_formatter(y_formatter)

x1, y1 = plot_cov2("50_2-12_ind", contig)
x2, y2 = plot_cov2("50_2-13_ind", contig)
x3, y3 = plot_cov2("50_3-6_ind", contig)
x4, y4 = plot_cov2("50_3-27_ind", contig)

d = {}

ax = subplot(2,3,2)
ax.plot(x1,y1, label="t1", color="black", ls="solid")
ax.plot(x2,y2, label="t2", color="orange", ls="solid")
ax.plot(x3,y3, label="t3", color="red", ls="solid")
ax.plot(x4,y4, label="t4", color="blue", ls="dotted")
tickies = map(int, ax.xaxis.get_majorticklocs())
ax.set_xticklabels(tickies, rotation=90 )
y_formatter = matplotlib.ticker.ScalarFormatter(useOffset=False)
ax.yaxis.set_major_formatter(y_formatter)

x1, y1 = plot_cov2("50_2-12_vlp", contig)
x2, y2 = plot_cov2("50_2-13_vlp", contig)
x3, y3 = plot_cov2("50_3-6_vlp", contig)
x4, y4 = plot_cov2("50_3-27_vlp", contig)

d = {}

ax = subplot(2,3,3)
ax.plot(x1,y1, label="t1", color="black", ls="solid")
ax.plot(x2,y2, label="t2", color="orange", ls="solid")
ax.plot(x3,y3, label="t3", color="red", ls="solid")
ax.plot(x4,y4, label="t4", color="blue", ls="dotted")
tickies = map(int, ax.xaxis.get_majorticklocs())
ax.set_xticklabels(tickies, rotation=90 )
y_formatter = matplotlib.ticker.ScalarFormatter(useOffset=False)
ax.yaxis.set_major_formatter(y_formatter)

x1, y1 = plot_cov2("77_2-18_total", contig)
x3, y3 = plot_cov2("77_3-12_total", contig)
x4, y4 = plot_cov2("77_4-2_total", contig)


ax = subplot(2,3,4)
ax.plot(x1,y1, label="t1", color="black", ls="solid")
ax.plot(x3,y3, label="t3", color="red", ls="solid")
ax.plot(x4,y4, label="t4", color="blue", ls="dotted")
tickies = map(int, ax.xaxis.get_majorticklocs())
ax.set_xticklabels(tickies, rotation=90 )
y_formatter = matplotlib.ticker.ScalarFormatter(useOffset=False)
ax.yaxis.set_major_formatter(y_formatter)

x1, y1 = plot_cov2("77_2-18_ind", contig)
x2, y2 = plot_cov2("77_2-19_ind", contig)
x3, y3 = plot_cov2("77_3-12_ind", contig)
x4, y4 = plot_cov2("77_4-2_ind", contig)
#ax.legend()

d = {}

ax = subplot(2,3,5)
ax.plot(x1,y1, label="t1", color="black", ls="solid")
ax.plot(x2,y2, label="t2", color="orange", ls="solid")
ax.plot(x3,y3, label="t3", color="red", ls="solid")
ax.plot(x4,y4, label="t4", color="blue", ls="dotted")
tickies = map(int, ax.xaxis.get_majorticklocs())
ax.set_xticklabels(tickies, rotation=90 )
y_formatter = matplotlib.ticker.ScalarFormatter(useOffset=False)
ax.yaxis.set_major_formatter(y_formatter)
#ax.legend()


x1, y1 = plot_cov2("77_2-18_vlp", contig)
x2, y2 = plot_cov2("77_2-19_vlp", contig)
x3, y3 = plot_cov2("77_3-12_vlp", contig)
x4, y4 = plot_cov2("77_4-2_vlp", contig)


ax = subplot(2,3,6)

ax.plot(x1,y1, label="t1", color="black", ls="solid")
ax.plot(x2,y2, label="t2", color="orange", ls="solid")
ax.plot(x3,y3, label="t3", color="red", ls="solid")
ax.plot(x4,y4, label="t4", color="blue", ls="dotted")
ax.set_xticklabels(ax.xaxis.get_majorticklocs(), rotation=90 )
tickies = map(int, ax.xaxis.get_majorticklocs())
ax.set_xticklabels(tickies, rotation=90 )
y_formatter = matplotlib.ticker.ScalarFormatter(useOffset=False)
ax.yaxis.set_major_formatter(y_formatter)

savefig(key + ".png")
#ax.legend()
# Out:
# 4
# 4
# 4

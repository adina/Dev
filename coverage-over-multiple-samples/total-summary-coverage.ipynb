# %%
# !ls *ind*total
# Out:
# 50_2-12_ind_norm.total 50_3-6_ind_norm.total  77_3-12_ind_norm.total
# 50_2-13_ind_norm.total 77_2-18_ind_norm.total 77_4-2_ind_norm.total
# 50_3-27_ind_norm.total 77_2-19_ind_norm.total

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.pyplot as plt

pylab.rcParams['figure.figsize'] = (15.0, 15.0)

d = {}

for f in ['50_2-12_total_norm.total', '50_3-6_total_norm.total', '50_3-27_total_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]


key_list = d.keys()
fig, axs = plt.subplots(nrows=3, ncols=2)
x = [0, 22, 43]
#ax.errorbar(x, y2, yerr=yerr, fmt='o')
#ax.errorbar(2*x, y2, yerr=yerr, fmt='o')
#ax.set_title('Vert. symmetric')

ax = axs[0,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF Total Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)

d = {}

for f in ['77_2-18_total_norm.total', '77_3-12_total_norm.total', '77_4-2_total_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 22, 43]
ax = axs[0,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF Total Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)

d = {}

for f in ['50_2-12_ind_norm.total', '50_2-13_ind_norm.total', '50_3-6_ind_norm.total', '50_3-27_ind_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[1,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF IND Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)

d = {}

for f in ['77_2-18_ind_norm.total', '77_2-19_ind_norm.total', '77_3-12_ind_norm.total', '77_4-2_ind_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[1,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF IND Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)

d = {}

for f in ['50_2-12_vlp_norm.total', '50_2-13_vlp_norm.total', '50_3-6_vlp_norm.total', '50_3-27_vlp_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[2,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF VLP Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)

d = {}

for f in ['77_2-18_vlp_norm.total', '77_2-19_vlp_norm.total', '77_3-12_vlp_norm.total', '77_4-2_vlp_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[2,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF VLP Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')

ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)
# Out:
# (0, 0.014999999999999999)

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.pyplot as plt

pylab.rcParams['figure.figsize'] = (15.0, 15.0)

d = {}

for f in ['50_2-12_total_norm.total', '50_3-6_total_norm.total', '50_3-27_total_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]


key_list = d.keys()
fig, axs = plt.subplots(nrows=3, ncols=2)
x = [0, 22, 43]
#ax.errorbar(x, y2, yerr=yerr, fmt='o')
#ax.errorbar(2*x, y2, yerr=yerr, fmt='o')
#ax.set_title('Vert. symmetric')

ax = axs[0,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF Total Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(0, 5e-5)

d = {}

for f in ['77_2-18_total_norm.total', '77_3-12_total_norm.total', '77_4-2_total_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 22, 43]
ax = axs[0,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF Total Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(0, 5e-5)

d = {}

for f in ['50_2-12_ind_norm.total', '50_2-13_ind_norm.total', '50_3-6_ind_norm.total', '50_3-27_ind_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[1,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF IND Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(0, 5e-4)

d = {}

for f in ['77_2-18_ind_norm.total', '77_2-19_ind_norm.total', '77_3-12_ind_norm.total', '77_4-2_ind_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[1,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF IND Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(0, 1e-4)

d = {}

for f in ['50_2-12_vlp_norm.total', '50_2-13_vlp_norm.total', '50_3-6_vlp_norm.total', '50_3-27_vlp_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[2,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF VLP Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(0, 5e-5)

d = {}

for f in ['77_2-18_vlp_norm.total', '77_2-19_vlp_norm.total', '77_3-12_vlp_norm.total', '77_4-2_vlp_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[2,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF VLP Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')

ax.locator_params(nbins=5)
ax.set_ylim(0, 5e-5)
# Out:
# (0, 5e-05)

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.pyplot as plt

pylab.rcParams['figure.figsize'] = (15.0, 15.0)

d = {}

for f in ['50_2-12_total_norm.total', '50_3-6_total_norm.total', '50_3-27_total_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]


key_list = d.keys()
fig, axs = plt.subplots(nrows=3, ncols=2)
x = [0, 22, 43]
#ax.errorbar(x, y2, yerr=yerr, fmt='o')
#ax.errorbar(2*x, y2, yerr=yerr, fmt='o')
#ax.set_title('Vert. symmetric')

ax = axs[0,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF Total Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(0, 5e-5)

d = {}

for f in ['77_2-18_total_norm.total', '77_3-12_total_norm.total', '77_4-2_total_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 22, 43]
ax = axs[0,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF Total Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(0, 5e-5)

d = {}

for f in ['50_2-12_ind_norm.total', '50_2-13_ind_norm.total', '50_3-6_ind_norm.total', '50_3-27_ind_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[1,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF IND Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)

ax.set_xlim(0,2)
d = {}

for f in ['77_2-18_ind_norm.total', '77_2-19_ind_norm.total', '77_3-12_ind_norm.total', '77_4-2_ind_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[1,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF IND Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)

ax.set_xlim(0,2)
d = {}

for f in ['50_2-12_vlp_norm.total', '50_2-13_vlp_norm.total', '50_3-6_vlp_norm.total', '50_3-27_vlp_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[2,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF VLP Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(0, 7e-5)
ax.set_xlim(0,2)
d = {}

for f in ['77_2-18_vlp_norm.total', '77_2-19_vlp_norm.total', '77_3-12_vlp_norm.total', '77_4-2_vlp_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[2,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF VLP Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')

ax.locator_params(nbins=5)
ax.set_ylim(0, 5e-5)
ax.set_xlim(0,2)
# Out:
# (0, 2)

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.pyplot as plt

pylab.rcParams['figure.figsize'] = (15.0, 15.0)

d = {}

for f in ['50_2-12_total_norm.total', '50_3-6_total_norm.total', '50_3-27_total_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]


key_list = d.keys()
fig, axs = plt.subplots(nrows=3, ncols=2)
x = [0, 22, 43]
#ax.errorbar(x, y2, yerr=yerr, fmt='o')
#ax.errorbar(2*x, y2, yerr=yerr, fmt='o')
#ax.set_title('Vert. symmetric')

ax = axs[0,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF Total Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)

d = {}

for f in ['77_2-18_total_norm.total', '77_3-12_total_norm.total', '77_4-2_total_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 22, 43]
ax = axs[0,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF Total Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)

d = {}

for f in ['50_2-12_ind_norm.total', '50_2-13_ind_norm.total', '50_3-6_ind_norm.total', '50_3-27_ind_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[1,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF IND Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)

d = {}

for f in ['77_2-18_ind_norm.total', '77_2-19_ind_norm.total', '77_3-12_ind_norm.total', '77_4-2_ind_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[1,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF IND Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)

d = {}

for f in ['50_2-12_vlp_norm.total', '50_2-13_vlp_norm.total', '50_3-6_vlp_norm.total', '50_3-27_vlp_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[2,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF VLP Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)

d = {}

for f in ['77_2-18_vlp_norm.total', '77_2-19_vlp_norm.total', '77_3-12_vlp_norm.total', '77_4-2_vlp_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [0, 1, 22, 43]
ax = axs[2,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF VLP Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')

ax.locator_params(nbins=5)
ax.set_ylim(0,5e-5)
# Out:
# (0, 5e-05)

# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.pyplot as plt

pylab.rcParams['figure.figsize'] = (15.0, 15.0)

d = {}

for f in ['50_2-12_total_norm.total', '50_3-6_total_norm.total', '50_3-27_total_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]


key_list = d.keys()
fig, axs = plt.subplots(nrows=3, ncols=2)
x = [1, 3, 4]
#ax.errorbar(x, y2, yerr=yerr, fmt='o')
#ax.errorbar(2*x, y2, yerr=yerr, fmt='o')
#ax.set_title('Vert. symmetric')

ax = axs[0,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF Total Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)
ax.set_xlim(0,5)

d = {}

for f in ['77_2-18_total_norm.total', '77_3-12_total_norm.total', '77_4-2_total_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [1, 3, 4]
ax = axs[0,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF Total Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)
ax.set_xlim(0,5)

d = {}

for f in ['50_2-12_ind_norm.total', '50_2-13_ind_norm.total', '50_3-6_ind_norm.total', '50_3-27_ind_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [1, 2, 3, 4]
ax = axs[1,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF IND Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)
ax.set_xlim(0,5)

d = {}

for f in ['77_2-18_ind_norm.total', '77_2-19_ind_norm.total', '77_3-12_ind_norm.total', '77_4-2_ind_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [1, 2, 3, 4]
ax = axs[1,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF IND Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)
ax.set_xlim(0,5)

d = {}

for f in ['50_2-12_vlp_norm.total', '50_2-13_vlp_norm.total', '50_3-6_vlp_norm.total', '50_3-27_vlp_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [1, 2, 3, 4]
ax = axs[2,0]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('LF VLP Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')
ax.locator_params(nbins=5)
ax.set_ylim(bottom=0)
ax.set_xlim(0,5)

d = {}

for f in ['77_2-18_vlp_norm.total', '77_2-19_vlp_norm.total', '77_3-12_vlp_norm.total', '77_4-2_vlp_norm.total']:
    for line in open(f):
        id, med, se = line.rstrip().split(' ')
        if d.has_key(id):
            inf = (med, se)
            d[id].append(inf)
        else:
            d[id] = [(med, se)]

x = [1, 2, 3, 4]
ax = axs[2,1]

for n in range(0, len(d.keys())):
    y = []
    y_err = []
    for i in d[key_list[n]]:
        y.append(float(i[0]))
        y_err.append(float(i[1]))
    ax.errorbar(x, y, yerr=y_err, fmt='-o', ls='--')
    ax.set_title('MF VLP Fraction')
    ax.set_xlabel('Day')
    ax.set_ylabel('Relative Abundance')

ax.locator_params(nbins=5)
ax.set_ylim(0,5e-5)
ax.set_xlim(0,5)
# Out:
# (0, 5)
